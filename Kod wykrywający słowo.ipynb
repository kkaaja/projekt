# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dane_03-bezpomyłki.csv')

# %%
df
# Out:
#              signal          time
# 0     -35487.361417  1.669884e+09
# 1    -116295.290719  1.669884e+09
# 2    -163329.770612  1.669884e+09
# 3    -146895.149632  1.669884e+09
# 4    -110472.730820  1.669884e+09
# ...             ...           ...
# 7418   -1245.833159  1.669884e+09
# 7419    -324.940423  1.669884e+09
# 7420   -4829.437794  1.669884e+09
# 7421   -8640.985695  1.669884e+09
# 7422   -8246.734322  1.669884e+09
#
# [7423 rows x 2 columns]

# %%
litery = pd.read_csv("litery-czas3.txt")

# %%
litery
# Out:
#    litera          czas
# 0       a  1.669884e+09
# 1       b  1.669884e+09
# 2       c  1.669884e+09
# 3       d  1.669884e+09
# 4       e  1.669884e+09
# 5       f  1.669884e+09
# 6       g  1.669884e+09
# 7       h  1.669884e+09
# 8       i  1.669884e+09
# 9       j  1.669884e+09
# 10      k  1.669884e+09
# 11      l  1.669884e+09
# 12      ł  1.669884e+09
# 13      m  1.669884e+09
# 14      n  1.669884e+09
# 15      o  1.669884e+09
# 16      p  1.669884e+09
# 17      r  1.669884e+09
# 18      s  1.669884e+09
# 19      t  1.669884e+09
# 20      u  1.669884e+09
# 21      w  1.669884e+09
# 22      x  1.669884e+09
# 23      a  1.669884e+09
# 24      b  1.669884e+09
# 25      c  1.669884e+09
# 26      d  1.669884e+09
# 27      e  1.669884e+09
# 28      f  1.669884e+09
# 29      g  1.669884e+09
# 30      h  1.669884e+09
# 31      i  1.669884e+09
# 32      j  1.669884e+09
# 33      k  1.669884e+09
# 34      l  1.669884e+09
# 35      ł  1.669884e+09
# 36      m  1.669884e+09
# 37      n  1.669884e+09
# 38      o  1.669884e+09
# 39      p  1.669884e+09
# 40      r  1.669884e+09
# 41      s  1.669884e+09
# 42      t  1.669884e+09
# 43      u  1.669884e+09
# 44      w  1.669884e+09
# 45      x  1.669884e+09
# 46      y  1.669884e+09
# 47      z  1.669884e+09
# 48      a  1.669884e+09
# 49      b  1.669884e+09
# 50      c  1.669884e+09
# 51      d  1.669884e+09
# 52      e  1.669884e+09

# %%
t = np.linspace(0, len(df['signal'])/250, len(df['signal']))
plt.plot(t, df['signal'])

# %%
sygnal = np.array(df['signal'][250:])

# %%
t = np.linspace(0, len(sygnal)/250, len(sygnal))
plt.plot(t, sygnal)
plt.xlim([16,20])
# Out:
# (16.0, 20.0)

# %%
lista=[] #lista w której zapisują się wykryte mrugnięcia
for i in range(len(sygnal)):
    if sygnal[i]<-30000 and sygnal[i-1]>-30000:
        lista.append(df['time'][i])
lista1=lista[:]

# %%
print(lista)
print(lista1)
# Out:
# [1669884024.2870047, 1669884024.292789, 1669884031.2115412, 1669884039.7839324, 1669884039.8340764, 1669884039.8795817, 1669884039.881118, 1669884039.8819056, 1669884048.0690527]
# [1669884024.2870047, 1669884024.292789, 1669884031.2115412, 1669884039.7839324, 1669884039.8340764, 1669884039.8795817, 1669884039.881118, 1669884039.8819056, 1669884048.0690527]

# %%
for i in range(len(lista1)-1):
    if lista1[i+1]-lista1[i]<0.3:
        lista.remove(lista[i])
        i+1

print(lista)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [30], line 3
#       1 for i in range(len(lista1)-1):
#       2     if lista1[i+1]-lista1[i]<0.3:
# ----> 3         lista.remove(lista[i])
#       4         i+1
#       6 print(lista)
#
# IndexError: list index out of range

# %%
slowo=[]
for i in range(len(lista)): 
    for y in range(len(litery)):
            if lista[i] >= litery['czas'][y] and lista[i] < litery['czas'][y+1]:
                slowo.append(litery['litera'][y+1])
                i+1
            else:
                y+1

# %%
slowo=''.join(slowo)
print(slowo)
# Out:
# birrr
